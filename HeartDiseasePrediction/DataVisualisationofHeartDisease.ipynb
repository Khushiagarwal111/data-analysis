# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df= pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ### **Heart Disease EDA - Age (DistPlot)**

# %%
sns.distplot(df['Age'], kde='True', color='green',hist=True)
# Out:
# <ipython-input-5-84d73b0b2203>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde='True', color='green',hist=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['Age'],kde=True, color='blue')

# %%
sns.displot(x=df['ChestPainType'],kde=True, color='blue')

# %%
sns.displot(x=df['Cholesterol'],kde=True, color='blue')

# %%
sns.displot(x=df['MaxHR'],kde=True, color='blue')

# %%
sns.displot(df['RestingBP'], kde=True, color='blue')

# %%
sns.displot(df['Cholesterol'], kde=True, color='blue')

# %%
sns.displot(df['MaxHR'], kde=True, color='blue')

# %%
sns.displot(df['Oldpeak'], kde=True, color='blue')

# %% [markdown]
# ### **Heart Disease EDA - Categorical Columns (Pie Charts)**

# %% [markdown]
# **Pie Charts for** **Categorial**

# %%
df.groupby('Sex').size().plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie', autopct='%.1f')
# Out:
# <Axes: >

# %% [markdown]
# ### Heart Disease EDA - **ViolinPlot**

# %% [markdown]
# ### Violin **Plot**

# %%
sns.violinplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(x=df['RestingBP'])
# Out:
# <Axes: xlabel='RestingBP'>

# %%
sns.violinplot(y=df['Sex'], x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Sex'], x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y = df['RestingBP'], x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y=df['RestingBP'], x=df['Cholesterol'])
# Out:
# <Axes: xlabel='Cholesterol', ylabel='RestingBP'>

# %%
df['Sex'] = df['Sex'].astype(bool)

# %%
df.head()
# Out:
#    Age   Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40  True           ATA        140          289          0     Normal
# 1   49  True           NAP        160          180          0     Normal
# 2   37  True           ATA        130          283          0         ST
# 3   48  True           ASY        138          214          0     Normal
# 4   54  True           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# JOINT PLOT

# %%
sns.jointplot(x='HeartDisease', y='Oldpeak', data=df)

# %%
sns.jointplot(x='Age', y='MaxHR', data=df, kind='reg')

# %%
sns.jointplot(x='Cholesterol', y='FastingBS', data=df, kind='reg')

# %%
sns.jointplot(x='HeartDisease', y='MaxHR', data=df, kind='reg')

# %%
sns.jointplot(x='Cholesterol', y='MaxHR', data=df, kind='reg')

# %% [markdown]
# ### PairPlot

# %%
sns.pairplot(df)
